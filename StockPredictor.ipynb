# %% [markdown]
# <a href="https://colab.research.google.com/github/Samantha996/Personal-Site/blob/main/StockPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Building a Stock Portfolio Tool using Python

# %% [markdown]
# Step 1: Importing the Correct Libries we will be using.

# %%
import pandas as pd
import numpy as np
import requests
from pandas_datareader import data
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression # train model
import pickle # save model in pickle format. Prevents re-training

# %%
stock = 'ZM'
def get_data():
  start = "01-01-2013"
  df = data.DataReader(stock,"yahoo",start = start)
  df.to_csv(f"{stock}_20210211.csv")
  print(df.head())
get_data()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2019-04-18  66.000000  60.320999  65.000000  62.000000  25764700  62.000000
# 2019-04-22  68.900002  59.939999  61.000000  65.699997   9949700  65.699997
# 2019-04-23  74.168999  65.550003  66.870003  69.000000   6786500  69.000000
# 2019-04-24  71.500000  63.160000  71.400002  63.200001   4973500  63.200001
# 2019-04-25  66.849998  62.599998  64.739998  65.000000   3863300  65.000000

# %%
df = pd.read_csv(f"{stock}_20210211.csv", index_col=0)
df.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2019-04-18  66.000000  60.320999  65.000000  62.000000  25764700  62.000000
# 2019-04-22  68.900002  59.939999  61.000000  65.699997   9949700  65.699997
# 2019-04-23  74.168999  65.550003  66.870003  69.000000   6786500  69.000000
# 2019-04-24  71.500000  63.160000  71.400002  63.200001   4973500  63.200001
# 2019-04-25  66.849998  62.599998  64.739998  65.000000   3863300  65.000000

# %%
df['HL_pct'] = (df['High']-df['Low'])/df['Low']*100.0
df = df[['Adj Close', 'Volume', 'HL_pct']]
df.head()
# Out:
#             Adj Close    Volume     HL_pct
# Date
# 2019-04-18  62.000000  25764700   9.414633
# 2019-04-22  65.699997   9949700  14.948287
# 2019-04-23  69.000000   6786500  13.148734
# 2019-04-24  63.200001   4973500  13.204560
# 2019-04-25  65.000000   3863300   6.789138

# %%
predict_col = 'Adj Close'
df.fillna(0, inplace =True)

df['future3days'] = df[predict_col].shift(-3)
df.dropna(inplace = True)
df.head()
# Out:
#             Adj Close    Volume     HL_pct  future3days
# Date
# 2019-04-18  62.000000  25764700   9.414633    63.200001
# 2019-04-22  65.699997   9949700  14.948287    65.000000
# 2019-04-23  69.000000   6786500  13.148734    66.220001
# 2019-04-24  63.200001   4973500  13.204560    68.169998
# 2019-04-25  65.000000   3863300   6.789138    72.470001

# %%
#input variables
X = np.array(df.drop(['future3days'], 1))
X = preprocessing.scale(X)
y = np.array(df['future3days'])

#test and train data
#X-Train - input training, x_test - input for pred data
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.3)

#Multiple Linear Regression Model
clf = LinearRegression()
clf.fit(X_train, y_train)

#saving in pickle format to not have to run model again
with open(f'{stock}_predictionmodel.pickle', 'wb') as f:
  pickle.dump(clf, f)

#Accuracy score
confidence = clf.score(X_train, y_train)
print("Accuracy:", confidence)
# Out:
# Accuracy: 0.9808754914482374

# %%
#with open(f'{stock}_predictionmodel.pickle', 'rb') as f:
 # clf = pickle.load(f)

#confidence = clf.score(X_train, y_train)
#print("Accuracy:", confidence)
# Out:
# Accuracy: 0.9931878908947266

# %%
for X, y in zip(X_test, y_test):
  print(f"Model predicted price (3days in future):{clf.predict([X])[0]}, Actual price at 3 days later: {y}" )
# Out:
# Model predicted price (3days in future):97.21528714492466, Actual price at 3 days later: 91.7300033569336
# Model predicted price (3days in future):112.71734408097855, Actual price at 3 days later: 111.0999984741211
# Model predicted price (3days in future):412.78010621077317, Actual price at 3 days later: 430.2799987792969
# Model predicted price (3days in future):71.95820163779898, Actual price at 3 days later: 65.0
# Model predicted price (3days in future):78.4208828772791, Actual price at 3 days later: 70.44000244140625
# Model predicted price (3days in future):387.54479182777214, Actual price at 3 days later: 430.0299987792969
# Model predicted price (3days in future):106.56868790670664, Actual price at 3 days later: 105.01000213623048
# Model predicted price (3days in future):84.10969060467576, Actual price at 3 days later: 78.04000091552734
# Model predicted price (3days in future):205.76433386773087, Actual price at 3 days later: 219.5200042724609
# Model predicted price (3days in future):68.97182348339672, Actual price at 3 days later: 70.38999938964844
# Model predicted price (3days in future):98.64540809048049, Actual price at 3 days later: 95.4499969482422
# Model predicted price (3days in future):69.92974976344354, Actual price at 3 days later: 68.18000030517578
# Model predicted price (3days in future):75.09851156936887, Actual price at 3 days later: 73.08999633789062
# Model predicted price (3days in future):91.4189751409222, Actual price at 3 days later: 90.9499969482422
# Model predicted price (3days in future):252.00748099954416, Actual price at 3 days later: 250.0
# Model predicted price (3days in future):138.90812141004744, Actual price at 3 days later: 151.6999969482422
# Model predicted price (3days in future):247.59983099873466, Actual price at 3 days later: 276.79998779296875
# Model predicted price (3days in future):71.05410722075405, Actual price at 3 days later: 70.08000183105469
# Model predicted price (3days in future):82.0830789792827, Actual price at 3 days later: 102.0
# Model predicted price (3days in future):483.2180594169691, Actual price at 3 days later: 482.989990234375
# Model predicted price (3days in future):94.84900458610129, Actual price at 3 days later: 92.69000244140624
# Model predicted price (3days in future):71.92605772519994, Actual price at 3 days later: 67.73999786376953
# Model predicted price (3days in future):77.27903701601208, Actual price at 3 days later: 79.18000030517578
# Model predicted price (3days in future):146.55981101680453, Actual price at 3 days later: 143.44000244140625
# Model predicted price (3days in future):404.6278329825856, Actual price at 3 days later: 397.9599914550781
# Model predicted price (3days in future):381.6264787412164, Actual price at 3 days later: 353.75
# Model predicted price (3days in future):393.523947751731, Actual price at 3 days later: 401.6199951171875
# Model predicted price (3days in future):404.9728466484543, Actual price at 3 days later: 468.4700012207031
# Model predicted price (3days in future):176.16687357779617, Actual price at 3 days later: 164.0
# Model predicted price (3days in future):477.53180445275785, Actual price at 3 days later: 480.6099853515625
# Model predicted price (3days in future):205.30019920327422, Actual price at 3 days later: 210.3500061035156
# Model predicted price (3days in future):76.62305322538343, Actual price at 3 days later: 75.55999755859375
# Model predicted price (3days in future):71.41484928665379, Actual price at 3 days later: 69.88999938964844
# Model predicted price (3days in future):99.82755387794562, Actual price at 3 days later: 100.29000091552734
# Model predicted price (3days in future):486.63072117290204, Actual price at 3 days later: 536.4000244140625
# Model predicted price (3days in future):410.21219273486406, Actual price at 3 days later: 412.0
# Model predicted price (3days in future):89.33522978086796, Actual price at 3 days later: 76.25
# Model predicted price (3days in future):420.2137071403735, Actual price at 3 days later: 350.8800048828125
# Model predicted price (3days in future):447.5786468803872, Actual price at 3 days later: 500.1099853515625
# Model predicted price (3days in future):93.68096551989794, Actual price at 3 days later: 91.4000015258789
# Model predicted price (3days in future):114.32620095904217, Actual price at 3 days later: 130.55000305175778
# Model predicted price (3days in future):81.38058834246822, Actual price at 3 days later: 80.41999816894531
# Model predicted price (3days in future):77.28362346658717, Actual price at 3 days later: 69.95999908447266
# Model predicted price (3days in future):96.2316985344275, Actual price at 3 days later: 93.87999725341795
# Model predicted price (3days in future):82.51718256284397, Actual price at 3 days later: 75.7699966430664
# Model predicted price (3days in future):169.03790878583314, Actual price at 3 days later: 164.69000244140625
# Model predicted price (3days in future):379.6891485095782, Actual price at 3 days later: 389.9800109863281
# Model predicted price (3days in future):260.8782052037662, Actual price at 3 days later: 252.3300018310547
# Model predicted price (3days in future):381.15520867160234, Actual price at 3 days later: 408.1700134277344
# Model predicted price (3days in future):96.88705273447626, Actual price at 3 days later: 92.6500015258789
# Model predicted price (3days in future):133.39084806662254, Actual price at 3 days later: 138.11000061035156
# Model predicted price (3days in future):74.73441548348953, Actual price at 3 days later: 72.62000274658203
# Model predicted price (3days in future):380.8017019273715, Actual price at 3 days later: 391.8299865722656
# Model predicted price (3days in future):290.07212896086975, Actual price at 3 days later: 290.44000244140625
# Model predicted price (3days in future):95.1882965993866, Actual price at 3 days later: 99.8000030517578
# Model predicted price (3days in future):242.17349548222703, Actual price at 3 days later: 243.47999572753903
# Model predicted price (3days in future):396.62186338525896, Actual price at 3 days later: 406.010009765625
# Model predicted price (3days in future):82.50077002351306, Actual price at 3 days later: 94.87000274658205
# Model predicted price (3days in future):77.67381894713522, Actual price at 3 days later: 74.5
# Model predicted price (3days in future):410.9715332732103, Actual price at 3 days later: 428.6400146484375
# Model predicted price (3days in future):74.41744806131742, Actual price at 3 days later: 62.7400016784668
# Model predicted price (3days in future):130.3891581430692, Actual price at 3 days later: 117.80999755859376
# Model predicted price (3days in future):98.51070283635097, Actual price at 3 days later: 97.38999938964844
# Model predicted price (3days in future):72.92134920370277, Actual price at 3 days later: 73.16000366210938
# Model predicted price (3days in future):94.87779485767754, Actual price at 3 days later: 91.66999816894531
# Model predicted price (3days in future):77.65044563250348, Actual price at 3 days later: 79.62999725341797
# Model predicted price (3days in future):93.43376283485158, Actual price at 3 days later: 105.29000091552734
# Model predicted price (3days in future):73.25198704924505, Actual price at 3 days later: 66.80999755859375
# Model predicted price (3days in future):95.23116478427717, Actual price at 3 days later: 90.63999938964844
# Model predicted price (3days in future):407.9610659831403, Actual price at 3 days later: 432.7699890136719
# Model predicted price (3days in future):207.71897704728397, Actual price at 3 days later: 221.0200042724609
# Model predicted price (3days in future):340.62339265428955, Actual price at 3 days later: 356.80999755859375
# Model predicted price (3days in future):261.38264936318143, Actual price at 3 days later: 248.5399932861328
# Model predicted price (3days in future):74.9956883855965, Actual price at 3 days later: 66.22000122070311
# Model predicted price (3days in future):165.2640797166277, Actual price at 3 days later: 179.47999572753906
# Model predicted price (3days in future):105.95550325462118, Actual price at 3 days later: 95.51000213623048
# Model predicted price (3days in future):115.57758820750044, Actual price at 3 days later: 135.91999816894528
# Model predicted price (3days in future):153.75697713885862, Actual price at 3 days later: 148.99000549316406
# Model predicted price (3days in future):80.84732322034279, Actual price at 3 days later: 76.7300033569336
# Model predicted price (3days in future):513.9114564183117, Actual price at 3 days later: 559.0
# Model predicted price (3days in future):268.0027260945871, Actual price at 3 days later: 268.25
# Model predicted price (3days in future):90.53364835736669, Actual price at 3 days later: 88.63999938964844
# Model predicted price (3days in future):424.0794253419019, Actual price at 3 days later: 401.6300048828125
# Model predicted price (3days in future):70.41111394941927, Actual price at 3 days later: 68.0
# Model predicted price (3days in future):72.39285633166186, Actual price at 3 days later: 64.56999969482422
# Model predicted price (3days in future):88.52199670753495, Actual price at 3 days later: 85.44000244140625
# Model predicted price (3days in future):487.224655039141, Actual price at 3 days later: 509.25
# Model predicted price (3days in future):105.04948734900046, Actual price at 3 days later: 106.87999725341795
# Model predicted price (3days in future):117.76247733850613, Actual price at 3 days later: 110.3000030517578
# Model predicted price (3days in future):99.8611031970429, Actual price at 3 days later: 97.11000061035156
# Model predicted price (3days in future):163.65788841774005, Actual price at 3 days later: 141.14999389648438
# Model predicted price (3days in future):408.1340449220101, Actual price at 3 days later: 438.7300109863281
# Model predicted price (3days in future):96.31182408236845, Actual price at 3 days later: 80.3499984741211
# Model predicted price (3days in future):80.20713704613866, Actual price at 3 days later: 71.01000213623047
# Model predicted price (3days in future):169.37559889545935, Actual price at 3 days later: 173.67999267578125
# Model predicted price (3days in future):85.48427262724543, Actual price at 3 days later: 79.75
# Model predicted price (3days in future):99.15803842963477, Actual price at 3 days later: 93.66000366210938
# Model predicted price (3days in future):461.36083271349435, Actual price at 3 days later: 465.5
# Model predicted price (3days in future):109.51490854354947, Actual price at 3 days later: 105.0
# Model predicted price (3days in future):66.7144055911836, Actual price at 3 days later: 67.59999847412111
# Model predicted price (3days in future):84.66766298360677, Actual price at 3 days later: 84.63999938964844
# Model predicted price (3days in future):297.64982427479555, Actual price at 3 days later: 423.55999755859375
# Model predicted price (3days in future):378.4070278102858, Actual price at 3 days later: 410.80999755859375
# Model predicted price (3days in future):473.6605101954845, Actual price at 3 days later: 492.4100036621094
# Model predicted price (3days in future):108.74864468696231, Actual price at 3 days later: 107.08000183105469
# Model predicted price (3days in future):276.26842143579773, Actual price at 3 days later: 289.67999267578125
# Model predicted price (3days in future):71.12722796454123, Actual price at 3 days later: 66.45999908447266
# Model predicted price (3days in future):70.71332858943885, Actual price at 3 days later: 68.04000091552734
# Model predicted price (3days in future):95.589369591827, Actual price at 3 days later: 85.41000366210938
# Model predicted price (3days in future):69.2267676740885, Actual price at 3 days later: 62.06000137329102
# Model predicted price (3days in future):424.32130574119753, Actual price at 3 days later: 478.3599853515625
# Model predicted price (3days in future):94.88538381466795, Actual price at 3 days later: 90.16000366210938
# Model predicted price (3days in future):100.17335164784794, Actual price at 3 days later: 93.37999725341795
# Model predicted price (3days in future):358.50702328933994, Actual price at 3 days later: 342.5
# Model predicted price (3days in future):88.72024191829355, Actual price at 3 days later: 82.62999725341797
# Model predicted price (3days in future):488.05029572419573, Actual price at 3 days later: 496.5
# Model predicted price (3days in future):111.75355967575113, Actual price at 3 days later: 107.47000122070312
# Model predicted price (3days in future):173.82403319778211, Actual price at 3 days later: 161.97000122070312
# Model predicted price (3days in future):290.52899038567153, Actual price at 3 days later: 299.2699890136719
# Model predicted price (3days in future):436.2404264286783, Actual price at 3 days later: 443.7200012207031
# Model predicted price (3days in future):402.49357507360764, Actual price at 3 days later: 383.8800048828125
# Model predicted price (3days in future):176.1032463533923, Actual price at 3 days later: 175.47999572753906
# Model predicted price (3days in future):406.68712447751847, Actual price at 3 days later: 385.3599853515625
# Model predicted price (3days in future):92.67773333691235, Actual price at 3 days later: 89.86000061035156
# Model predicted price (3days in future):479.8982307482125, Actual price at 3 days later: 413.239990234375
# Model predicted price (3days in future):93.40925087267641, Actual price at 3 days later: 103.93000030517578
# Model predicted price (3days in future):474.1353741578338, Actual price at 3 days later: 518.7899780273439
# Model predicted price (3days in future):93.55898160334334, Actual price at 3 days later: 93.52999877929688
# Model predicted price (3days in future):389.6776798915961, Actual price at 3 days later: 378.5899963378906
# Model predicted price (3days in future):369.0857083280592, Actual price at 3 days later: 384.4800109863281
# Model predicted price (3days in future):293.69145036257834, Actual price at 3 days later: 457.6900024414063
# Model predicted price (3days in future):464.4395814636078, Actual price at 3 days later: 464.9800109863281
# Model predicted price (3days in future):65.49313303066927, Actual price at 3 days later: 63.52000045776367
# Model predicted price (3days in future):258.6293357166656, Actual price at 3 days later: 253.5399932861328
# Model predicted price (3days in future):76.49780282393289, Actual price at 3 days later: 74.08000183105469
# Model predicted price (3days in future):272.86919985789126, Actual price at 3 days later: 282.2799987792969
# Model predicted price (3days in future):109.60043522384797, Actual price at 3 days later: 113.11000061035156

# %%
df_test = pd.read_csv(f"{stock}_20210211.csv", index_col = 0)
df_test['HL_pct'] = (df_test['High']-df_test['Low'])/df_test['Low']*100.0
df_test = df_test[['Adj Close', 'Volume', 'HL_pct']]

X_new = np.array(df_test)
X_new = preprocessing.scale(X_new)

for x in (X_new):
  print(f"Model predicted price (3days in future): {clf.predict([x])[0]}")
# Out:
# Model predicted price (3days in future): 63.67519187738327
# Model predicted price (3days in future): 71.1346777018966
# Model predicted price (3days in future): 74.15513410791775
# Model predicted price (3days in future): 68.73497045346738
# Model predicted price (3days in future): 68.48607669800415
# Model predicted price (3days in future): 69.48397476554928
# Model predicted price (3days in future): 71.50660194036516
# Model predicted price (3days in future): 76.41817503952785
# Model predicted price (3days in future): 76.76598541082352
# Model predicted price (3days in future): 79.61908341052387
# Model predicted price (3days in future): 82.57230879099009
# Model predicted price (3days in future): 82.20466894041003
# Model predicted price (3days in future): 76.78406939669078
# Model predicted price (3days in future): 80.82557344212438
# Model predicted price (3days in future): 77.8589965693193
# Model predicted price (3days in future): 83.02423751116189
# Model predicted price (3days in future): 76.92492360156335
# Model predicted price (3days in future): 76.13643479448395
# Model predicted price (3days in future): 84.42765310994932
# Model predicted price (3days in future): 87.60761549402262
# Model predicted price (3days in future): 94.10858106393577
# Model predicted price (3days in future): 88.75016820694592
# Model predicted price (3days in future): 88.4075309171745
# Model predicted price (3days in future): 85.04030049820722
# Model predicted price (3days in future): 81.6223211544342
# Model predicted price (3days in future): 80.50180250864244
# Model predicted price (3days in future): 80.09980547857077
# Model predicted price (3days in future): 79.01051611256847
# Model predicted price (3days in future): 83.22949877575462
# Model predicted price (3days in future): 83.75742585370922
# Model predicted price (3days in future): 81.85327653152102
# Model predicted price (3days in future): 82.97363708205265
# Model predicted price (3days in future): 87.79700545119222
# Model predicted price (3days in future): 86.57346225839257
# Model predicted price (3days in future): 86.55567089409935
# Model predicted price (3days in future): 85.24945119145949
# Model predicted price (3days in future): 84.56792541271199
# Model predicted price (3days in future): 82.56772539972584
# Model predicted price (3days in future): 82.44375127913649
# Model predicted price (3days in future): 81.85016761427036
# Model predicted price (3days in future): 79.30241172308199
# Model predicted price (3days in future): 78.6938371495103
# Model predicted price (3days in future): 78.10372791021855
# Model predicted price (3days in future): 76.13591375652942
# Model predicted price (3days in future): 80.25715317220387
# Model predicted price (3days in future): 78.85238421253155
# Model predicted price (3days in future): 79.31968578966081
# Model predicted price (3days in future): 76.43636642321815
# Model predicted price (3days in future): 75.25528896528697
# Model predicted price (3days in future): 73.59077515838277
# Model predicted price (3days in future): 73.54197648896707
# Model predicted price (3days in future): 72.9012686724253
# Model predicted price (3days in future): 72.75278791677324
# Model predicted price (3days in future): 70.29636562602491
# Model predicted price (3days in future): 68.86489763277947
# Model predicted price (3days in future): 68.39329727284249
# Model predicted price (3days in future): 68.28686328929774
# Model predicted price (3days in future): 65.15520762930592
# Model predicted price (3days in future): 64.89726687177779
# Model predicted price (3days in future): 67.49472766619928
# Model predicted price (3days in future): 66.11632563872345
# Model predicted price (3days in future): 70.58349649532391
# Model predicted price (3days in future): 68.14222249276341
# Model predicted price (3days in future): 73.25580000243457
# Model predicted price (3days in future): 72.79828835347058
# Model predicted price (3days in future): 72.76310034196348
# Model predicted price (3days in future): 72.39845923623544
# Model predicted price (3days in future): 70.41270821447145
# Model predicted price (3days in future): 69.22746816898285
# Model predicted price (3days in future): 69.57527782594559
# Model predicted price (3days in future): 73.00475188309763
# Model predicted price (3days in future): 71.08219895929605
# Model predicted price (3days in future): 70.62439862145348
# Model predicted price (3days in future): 70.21082912443757
# Model predicted price (3days in future): 69.98243355730136
# Model predicted price (3days in future): 72.87657624150626
# Model predicted price (3days in future): 72.60121691009847
# Model predicted price (3days in future): 72.07059622174177
# Model predicted price (3days in future): 73.74574635845127
# Model predicted price (3days in future): 72.50562476660636
# Model predicted price (3days in future): 75.62967447790305
# Model predicted price (3days in future): 76.7982419024521
# Model predicted price (3days in future): 76.84834095774973
# Model predicted price (3days in future): 76.5329895486388
# Model predicted price (3days in future): 76.40743076952053
# Model predicted price (3days in future): 73.09807229364401
# Model predicted price (3days in future): 73.56771790959547
# Model predicted price (3days in future): 72.13208516965122
# Model predicted price (3days in future): 71.54045177813646
# Model predicted price (3days in future): 64.67510796930762
# Model predicted price (3days in future): 69.61230957685262
# Model predicted price (3days in future): 67.07772090415986
# Model predicted price (3days in future): 66.08446960445923
# Model predicted price (3days in future): 64.96671640937453
# Model predicted price (3days in future): 65.89367873135686
# Model predicted price (3days in future): 69.09610229806285
# Model predicted price (3days in future): 68.1778916866308
# Model predicted price (3days in future): 70.02320760797298
# Model predicted price (3days in future): 70.28285817946386
